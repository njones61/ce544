# %% [markdown]
# <a href="https://colab.research.google.com/github/njones61/ce544/blob/main/docs/unit1/08_wells/confined_KEY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Well Equation - Confined Aquifer
#
# Instructions: Create a plot of drawdown (h) vs. distance (r) for the following set of inputs.  Make your distance range from rw to R.  Experiment with K.
#
# ![confined aquifer](https://ce544.groups.et.byu.net/images/confined.png)
#
# $
# h = H + \frac{q}{2\pi kD}ln\left(r/R\right)
# $

# %%
# import libraries needed
import numpy as np
import matplotlib.pyplot as plt

# %%
# variables
q = 0.2   #[m^3/s]
k = 0.1   #[cm/s]
k = k/100 #[m/s]
D = 15    #[m]
H = 50    #[m]
R = 500   #[m]
rw = 0.1  #[m]

# %%
# def well function
def h(r):
    return H + (q/(2*np.pi*k*D))*np.log(r/R)

# %%
# Calculate h at rw
hw = h(rw)
print(f'The head at the well = {hw:.3f}')
# Out:
# The head at the well = 31.926

# %%
r = np.array([0.1, 1.25, 2.5, 5, 10, 25, 50, 75, 100, 125, 175, 225, 300, 325, 350, 375, 400, 425, 450, 475, 500])
head = h(r)
head
# Out:
# array([31.9259547 , 37.28571735, 38.75662135, 40.22752535, 41.69842935,
#        43.64285867, 45.11376267, 45.97418636, 46.58466668, 47.058192  ,
#        47.77220826, 48.30551404, 48.91599436, 49.08585026, 49.24311226,
#        49.38951968, 49.52647468, 49.65512412, 49.77641804, 49.89115225,
#        50.        ])

# %%
# Plot the head vs r
plt.figure(figsize=(10,4))
plt.plot(r, head)
plt.xlabel('r [m]')
plt.ylabel('Head [m]')
plt.title('Head vs r')
plt.show()
